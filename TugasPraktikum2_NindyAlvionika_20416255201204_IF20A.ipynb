# %%
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# Mounted at /content/drives/

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# membaca citra
baby = cv2.imread("/content/baby.jpg")

# %%
# menampilkan citra
print("Baby")
cv2_imshow(baby)
# Out:
# Baby
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F4977E97A50>

# %%
babybgr = cv2.cvtColor(baby, cv2.COLOR_RGB2BGR)
cv2_imshow(babybgr)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F4977E23D10>

# %%
babyabu = cv2.cvtColor(baby, cv2.COLOR_RGB2GRAY)
cv2_imshow(babyabu)
# Out:
# <PIL.Image.Image image mode=L size=1000x500 at 0x7F4977E18AD0>

# %%
babyhsv = cv2.cvtColor(baby, cv2.COLOR_RGB2HSV)
cv2_imshow(babyhsv)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F4977E97290>

# %%
px = baby[12,15]
print(px)
# Out:
# [144 138 139]
